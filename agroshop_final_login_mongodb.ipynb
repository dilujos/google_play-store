# %%
import pymongo

print("Welcome To Agri-Shop for FARMERS ONLINE SHOPPING:")
print("*****************************************************************")
matchFound=False


connect = pymongo.MongoClient("localhost",27017)
database = connect['Login']
collection = database["Registration"]




ask = input("1) Login\n2) Registration\n")

if ask=="2":
    name = input("Enter your name: ")
    username = input("Enter username: ")
    password = input("Enter the password: ")

    data = {"FName":name,"Name":username,"Password":password}
    collection.insert_one(data)
    print("Data inserted............. :)")
    matchFound=True

elif ask=="1":

    count = 5
    while True:
        username = input("Enter the username: ")
        counts=collection.count_documents({"Name":username})
        if counts>0:
            find=collection.find({"Name":username})
            for name in find:
                user = name['Name']
                password = name['password']
            while True:
                passwd = input("Enter the password: ")
                if passwd == password:
                    print("Login successfully!..........")
                    matchFound=True
                    break
                elif count==0:
                    print("Your account has blocked for 24hrs")
                    break

                else:
                    count-=1
                    print("Wrong password, try again, you have only %d chance"%(count))


            break

        elif count==0:
            print("Your account has blocked for 24hrs")
            break
        else:
            count-=1
            print("Wrong username, try again. you have only %d chance"%(count))
else:
    print("put proper value")


   


if matchFound==True:
    print("You are Registered here as a Farmer ........")
    print("You can sell and buy  products here......")
    print("*******************************************************************************")
    CONTAns=int(input("Do you want continue.......\n1)YES\n  2)NO "))
    while CONTAns==1:
        ans=int(input(" Do you want \n1)sell or \n 2)buy products:      "))
        if ans==1:
            pdtName=int(input("choose the item\n 1) Vegetables \n 2) Fruits      "))
            if pdtName==1:
                VName=input("Give Name    ")
                Vdescription=input("Give a small description about your product(eg:yellow grapes)   :        ")
                VSpecification=input("Origin(Place)       :         ")
                VPrize=int(input("Enter the amount(1 kg):             "))
                VSize=int(input("Give Size(1...in cm eg:2cm):    "))
                VStock=int(input(" Quantity   :    "))
                CONTAns=int(input("Do you want continue.......\n1)YES  \n2)NO      "))
                
            elif pdtName==2:
                
                FName=input("Give Name      ")
                Fdescription=input("Give a small description about your product(eg:yellow grapes) :     ")
                FSpecification=input("Origin(Place)       :         ")
                FPrize=int(input("Enter the amount:      "))
                FSize=int(input("Give Size(1...in cm eg:2cm):    "))
                FStock=int(input(" Quantity   :        "))
                CONTAns=int(input("Do you want continue.......1)YES  2)NO      "))
            elif pdtName==3:
                                 
                                  
                SName=input("Give Name     ")
                Sdescription=input("Give a small description about your product(eg:yellow grapes)     ")
                SSpecification=input("Origin(Place):     ")
                SPrize=int(input("Enter the amount:     "))
                SSize=int(input("Give Size:    "))
                SStock=int(input(" Quantity   :     "))
                CONTAns=int(input("Do you want continue.......\n1)YES  \n2)NO "))
            else:
                print("You entered the invalid option.....")
        elif ans==2:
                     
            
            
            #ListBuyItems=["vegetables","Fruits","Spices"]
            ansb=int(input("Do you want buy 1)Vegetables 2)Fruits      "))
            if ansb==1:
                                
                vegitems=int(input("Avilabile Vegetables\n 1) Brinjal \n2) Beans \n3)potato \n4)pumpkin     "))
                if vegitems==1:
                    
                    BrinjalAnsw1=int(input("How many kg you may  want   "))
                    PrizeBRInjal= BrinjalAnsw1*20
                    print("Total amount =",PrizeBRInjal)
                    CONTAns=int(input("Do you want continue.......1)YES  2)NO     "))
                elif vegitems==2:
                    
                    BeansAnsw1=int(input("How many kg you  may want        "))
                    PrizeBeans= BeansAnsw1*25
                    print("Total amount =",PrizeBeans)
                    CONTAns=int(input("Do you want continue.......\n1)YES \n 2)NO       "))
                elif vegitems==3:
                    
                    PotatoAnsw1=int(input("How many kg you  may want"))
                    PrizePotato= PotatoAnsw1*25
                    print("Total amount =",PrizePotato)
                    CONTAns=int(input("Do you want continue.......\n1)YES \n 2)NO     "))
                elif vegitems==4:
                    
                    PumpAnsw1=int(input("How many kg you  may want   "))
                    PrizePump=  PumpAnsw1*10
                    print("Total amount =", PrizePum)
                    CONTAns=int(input("Do you want continue.......\n1)YES \n 2)NO     "))
                    
            elif ansb==2:
                
                fruitsitems=int(input("Avilabile Fruits \n1) Apples \n2) Grapes \n3)Orange     "))
                if fruitsitems==1:
                    
                    FruitAnsw1=int(input("How many kg you may  want"))
                    PrizeFruit=  FruitAnsw1*80
                    print("Total amount =",PrizeFruit)
                    CONTAns=int(input("Do you want continue.......\n1)YES  2)NO       "))
                elif fruitsitems==2:
                    FruitAnsw2=int(input("How many kg you may  want"))
                    PrizeFruit2=  FruitAnsw2*80
                    print("Total amount =",PrizeFruit2)
                    CONTAns=int(input("Do you want continue.......\n1)YES  2)NO      "))
                elif fruitsitems==3:
                    FruitAnsw3=int(input("How many kg you  may want   "))
                    PrizeFruit3=  FruitAnsw3*80
                    print("Total amount =",PrizeFruit3)
                    CONTAns=int(input("Do you want continue.......\n1)YES  2)NO    "))
                else:
                    print("You entered the invalid option")
                    CONTAns=int(input("Do you want continue.......1)YES  2)NO    "))
            else:
                print("You entered the invalid option.......")
                CONTAns=int(input("Do you want continue.......\n 1)YES \n 2)NO     "))
                """elif matchFound==False:
                    print("You are not Registered here ....")
                    RegAns=int(input("Do you want Register with us \n 1)yes \n 2)No "))
                    if RegAns==1:
                        RName=input("Enter your name again..   ")
                        REmail=input("Enter your Email     ")
                        RPassw=input("Enter your Password   ")
                        RmobileNo=input("Enter your cellphone no    ")
                    else:
                        print("Thank you......")"""
else:
     print("You entered the invalid option        ")
     CONTAns=int(input("Do you want continue.......\n1)YES \n 2)NO  "))
# Out:
# Welcome To Agri-Shop for FARMERS ONLINE SHOPPING:
# *****************************************************************
# 1) Login
# 2) Registration
# 1
# Enter the username: dilu
# Enter the password: dilu123
# Login successfully!..........
# You are Registered here as a Farmer ........
# You can sell and buy  products here......
# *******************************************************************************
# Do you want continue.......
# 1)YES
#   2)NO 1
#  Do you want
# 1)sell or
#  2)buy products:      1
# choose the item
#  1) Vegetables
#  2) Fruits      1
# Give Name    beans
# Give a small description about your product(eg:yellow grapes)   :        green large beans
# Origin(Place)       :         kerala
# Enter the amount(1 kg):             5
# Give Size(1...in cm eg:2cm):    6
#  Quantity   :    23
# Do you want continue.......
# 1)YES
# 2)NO      2
